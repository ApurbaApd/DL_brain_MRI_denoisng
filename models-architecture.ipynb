# %%
from models import UNet, ResNetAE, CAE, VAE
import torch
from torchsummary import summary

# %%
# models = {
#     "UNet": UNet(),
#     "ResNetAE": ResNetAE(),
#     "CAE": CAE()
# }

# for name, model in models.items():
#     print(f"\n=== {name} Architecture ===")
#     print(model)
#     total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
#     print(f"Total trainable parameters: {total_params:,}")

# %%
# pip install torchsummary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = UNet().to(device)

summary(model, input_size=(1,128,128))  # 1 channel, 128x128 image
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 128, 128]             640
#               ReLU-2         [-1, 64, 128, 128]               0
#             Conv2d-3         [-1, 64, 128, 128]          36,928
#               ReLU-4         [-1, 64, 128, 128]               0
#         DoubleConv-5         [-1, 64, 128, 128]               0
#          MaxPool2d-6           [-1, 64, 64, 64]               0
#             Conv2d-7          [-1, 128, 64, 64]          73,856
#               ReLU-8          [-1, 128, 64, 64]               0
#             Conv2d-9          [-1, 128, 64, 64]         147,584
#              ReLU-10          [-1, 128, 64, 64]               0
#        DoubleConv-11          [-1, 128, 64, 64]               0
#         MaxPool2d-12          [-1, 128, 32, 32]               0
#            Conv2d-13          [-1, 256, 32, 32]         295,168
# ...

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = ResNetAE().to(device)

summary(model, input_size=(1,128,128))  # 1 channel, 128x128 image
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 128, 128]             640
#               ReLU-2         [-1, 64, 128, 128]               0
#             Conv2d-3         [-1, 64, 128, 128]          36,928
#        BatchNorm2d-4         [-1, 64, 128, 128]             128
#               ReLU-5         [-1, 64, 128, 128]               0
#             Conv2d-6         [-1, 64, 128, 128]          36,928
#        BatchNorm2d-7         [-1, 64, 128, 128]             128
#      ResidualBlock-8         [-1, 64, 128, 128]               0
#             Conv2d-9          [-1, 128, 64, 64]          73,856
#            Conv2d-10          [-1, 128, 64, 64]         147,584
#       BatchNorm2d-11          [-1, 128, 64, 64]             256
#              ReLU-12          [-1, 128, 64, 64]               0
#            Conv2d-13          [-1, 128, 64, 64]         147,584
# ...

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = VAE().to(device)

summary(model, input_size=(1,128,128))  # 1 channel, 128x128 image
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 32, 64, 64]             544
#             Conv2d-2           [-1, 64, 32, 32]          32,832
#             Conv2d-3          [-1, 128, 16, 16]         131,200
#             Linear-4                  [-1, 512]      16,777,728
#             Linear-5                  [-1, 512]      16,777,728
#             Linear-6                [-1, 32768]      16,809,984
#    ConvTranspose2d-7           [-1, 64, 32, 32]         131,136
#    ConvTranspose2d-8           [-1, 32, 64, 64]          32,800
#    ConvTranspose2d-9          [-1, 1, 128, 128]             513
# ...
# Total params: 50,694,465
# Trainable params: 50,694,465
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.06
# Forward/backward pass size (MB): 3.63
# Params size (MB): 193.38
# ...

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = CAE().to(device)

summary(model, input_size=(1,128,128))  # 1 channel, 128x128 image
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 32, 64, 64]             320
#               ReLU-2           [-1, 32, 64, 64]               0
#             Conv2d-3           [-1, 64, 32, 32]          18,496
#               ReLU-4           [-1, 64, 32, 32]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#               ReLU-6          [-1, 128, 16, 16]               0
#    ConvTranspose2d-7           [-1, 64, 32, 32]          73,792
#               ReLU-8           [-1, 64, 32, 32]               0
#    ConvTranspose2d-9           [-1, 32, 64, 64]          18,464
#              ReLU-10           [-1, 32, 64, 64]               0
#   ConvTranspose2d-11          [-1, 1, 128, 128]             289
#           Sigmoid-12          [-1, 1, 128, 128]               0
# ...
# Total params: 185,217
# Trainable params: 185,217
# ...
